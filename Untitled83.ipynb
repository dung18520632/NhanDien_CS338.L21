# %% [markdown]
# <a href="https://colab.research.google.com/github/dung18520632/NhanDien_CS338.L21/blob/main/Untitled83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/Data.zip

# %%
import scipy.io.wavfile
import numpy as np
import sys
import glob 
import librosa
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
mylist= os.listdir('/content/Data')
file_emotion=[]
for i in mylist:
  file_emotion.append(os.listdir('Data/'+i+"/"))
file_emotion=np.asarray(file_emotion).ravel()

# %%
feeling_list=[]
#print(file_emotion)
for item in file_emotion:
    if item[0:1]=='0' :
        feeling_list.append('Angry')
    elif item[0:1]=='1':
        feeling_list.append('Happy')
    elif item[0:1]=='3':
        feeling_list.append('Neutral')
    else:
        feeling_list.append('Sad')
labels = feeling_list

# %%
import itertools
import numpy as np
from scipy.stats import zscore
from IPython.display import Audio

# %%
sample_rate = 16000     
max_pad_len = 49100
signal = []
for index,f in enumerate(file_emotion):
    m=""
    if f[0:1]=='0' :
        m='Angry/'
    elif f[0:1]=='1':
        m='Happy/'
    elif f[0:1]=='3':
        m='Neutral/'
    else:
        m='Sad/'
    y, sample_rate = librosa.load('Data/'+m+f,sr=sample_rate,offset=0.5)
    y=zscore(y)
    if len(y) < max_pad_len:    
        y_padded = np.zeros(max_pad_len)
        y_padded[:len(y)] = y
        y = y_padded
    elif len(y) > max_pad_len:
        y = np.asarray(y[:max_pad_len])
    signal.append(y)
    if (index % 100 == 0):
            print("Import Data: RUNNING ... {} files".format(index))
# Out:
# Import Data: RUNNING ... 0 files
# Import Data: RUNNING ... 100 files
# Import Data: RUNNING ... 200 files
# Import Data: RUNNING ... 300 files

# %%
random_idx = np.random.randint(len(labels))
random_idx=1
random_label = labels[random_idx]
random_signal = signal[random_idx]
random_filename = file_emotion[random_idx]

# Plot signal wave
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(random_signal))/float(sample_rate), random_signal)
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' with label {}".format(random_filename, random_label), fontsize=18)
plt.show()

# Play audio file
print("Audio file '{}':".format(random_filename))
Audio(random_signal, rate=sample_rate)
# Out:
# Audio file '2_44.wav':
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
nb_augmented = 2

# Function to add noise to a signals with a desired Signal Noise ratio (SNR)
def noisy_signal(signal, snr_low=15, snr_high=30, nb_augmented=2):
    
    # Signal length
    signal_len = len(signal)

    # Generate White noise
    noise = np.random.normal(size=(nb_augmented, signal_len))
    
    # Compute signal and noise power
    s_power = np.sum((signal / (2.0 ** 15)) ** 2) / signal_len
    n_power = np.sum((noise / (2.0 ** 15)) ** 2, axis=1) / signal_len
    
    # Random SNR: Uniform [15, 30]
    snr = np.random.randint(snr_low, snr_high)
    
    # Compute K coeff for each noise
    K = np.sqrt((s_power / n_power) * 10 ** (- snr / 10))
    K = np.ones((signal_len, nb_augmented)) * K
    
    # Generate noisy signal
    return signal + K.T * noise

# %%
print("Data Augmentation: START")
augmented_signal = list(map(noisy_signal, signal))
print("Data Augmentation: END!")
# Out:
# Data Augmentation: START
# Data Augmentation: END!

# %%
import os
from glob import glob
import pickle
import itertools
import numpy as np
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

### Graph imports ###
import matplotlib.pyplot as plt
from PIL import Image

### Audio import ###
import librosa
import IPython
from IPython.display import Audio

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(np.arange(len(random_signal))/float(sample_rate), random_signal)
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' ".format(random_filename), fontsize=18)

# Plot signal wave with noise
plt.subplot(1,2,2)
plt.plot(np.arange(len(random_signal))/float(sample_rate), augmented_signal[random_idx][0])
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' with Noise".format(random_filename), fontsize=18)
plt.show()

# Play audio file
print("Audio file '{}':".format(random_filename))
IPython.display.display(Audio(random_signal, rate=sample_rate))

# Play same audio file with noise
print("Audio file '{}' with noise:".format(random_filename))
IPython.display.display(Audio(augmented_signal[random_idx][0], rate=sample_rate))
# Out:
# Audio file '2_44.wav':
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio file '2_44.wav' with noise:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def mel_spectrogram(y, sr=16000, n_fft=512, win_length=256, hop_length=128, window='hamming', n_mels=128, fmax=4000):
    
    # Compute spectogram
    mel_spect = np.abs(librosa.stft(y, n_fft=n_fft, window=window, win_length=win_length, hop_length=hop_length)) ** 2
    
    # Compute mel spectrogram
    mel_spect = librosa.feature.melspectrogram(S=mel_spect, sr=sr, n_mels=n_mels, fmax=fmax)
    
    # Compute log-mel spectrogram
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    
    return mel_spect

# %%
# Start feature extraction
print("Feature extraction: START")

# Compute spectogram for all audio file
mel_spect = np.asarray(list(map(mel_spectrogram, signal)))
augmented_mel_spect = [np.asarray(list(map(mel_spectrogram, augmented_signal[i]))) for i in range(len(augmented_signal))]

# Stop feature extraction
print("Feature extraction: END!")
# Out:
# Feature extraction: START
# Feature extraction: END!

# %%
# Plot one random Spectogram 
plt.figure(figsize=(20, 10))
plt.imshow(mel_spect[np.random.randint(len(mel_spect))], origin='lower', aspect='auto', cmap='viridis')
plt.title('Log-Mel Spectrogram of an audio file', fontsize=26)
plt.tight_layout()
plt.show()

# %%
MEL_SPECT_train, MEL_SPECT_test, AUG_MEL_SPECT_train, AUG_MEL_SPECT_test, label_train, label_test = train_test_split(mel_spect, augmented_mel_spect, labels, test_size=0.2,random_state=42)

# Build augmented labels and train
aug_label_train = np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))
AUG_MEL_SPECT_train = np.asarray(list(itertools.chain.from_iterable(AUG_MEL_SPECT_train)))

# Concatenate original and augmented
X_train = np.concatenate((MEL_SPECT_train, AUG_MEL_SPECT_train))
y_train = np.concatenate((label_train, aug_label_train))

# Build test set
X_test = MEL_SPECT_test
y_test = label_test

# Delete
# del MEL_SPECT_train, AUG_MEL_SPECT_train, label_train, aug_label_train, AUG_MEL_SPECT_test, MEL_SPECT_test, label_test
# del mel_spect, augmented_mel_spect, labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-275-6963358feb4a> in <module>()
# ----> 1 MEL_SPECT_train, MEL_SPECT_test, AUG_MEL_SPECT_train, AUG_MEL_SPECT_test, label_train, label_test = train_test_split(mel_spect, augmented_mel_spect, labels, test_size=0.2,random_state=42)
#       2
#       3 # Build augmented labels and train
#       4 aug_label_train = np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))
#       5 AUG_MEL_SPECT_train = np.asarray(list(itertools.chain.from_iterable(AUG_MEL_SPECT_train)))
#
# NameError: name 'mel_spect' is not defined

# %%
label_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-274-eba6fecc06c9> in <module>()
# ----> 1 label_train
#
# NameError: name 'label_train' is not defined

# %%
np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-261-fb9bf3c98adf> in <module>()
# ----> 1 np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))
#
# NameError: name 'label_train' is not defined

# %%
X_train.shape
# Out:
# (960, 128, 384)

# %%
# Time distributed parameters
win_ts = 128
hop_ts = 64

# Split spectrogram into frames
def frame(x, win_step=128, win_size=64):
    nb_frames = 1 + int((x.shape[2] - win_size) / win_step)
    frames = np.zeros((x.shape[0], nb_frames, x.shape[1], win_size)).astype(np.float32)
    for t in range(nb_frames):
        frames[:,t,:,:] = np.copy(x[:,:,(t * win_step):(t * win_step + win_size)]).astype(np.float32)
    return frames

# Frame for TimeDistributed model
X_train = frame(X_train, hop_ts, win_ts)
X_test = frame(X_test, hop_ts, win_ts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-950b83774617> in <module>()
#      12
#      13 # Frame for TimeDistributed model
# ---> 14 X_train = frame(X_train, hop_ts, win_ts)
#      15 X_test = frame(X_test, hop_ts, win_ts)
#
# <ipython-input-165-950b83774617> in frame(x, win_step, win_size)
#       8     frames = np.zeros((x.shape[0], nb_frames, x.shape[1], win_size)).astype(np.float32)
#       9     for t in range(nb_frames):
# ---> 10         frames[:,t,:,:] = np.copy(x[:,:,(t * win_step):(t * win_step + win_size)]).astype(np.float32)
#      11     return frames
#      12
#
# ValueError: could not broadcast input array from shape (960,5,128,128) into shape (960,5,128)

# %%
X_train.shape
# Out:
# (960, 5, 128, 128)

# %%
# Save Train and test set
pickle.dump(X_train.astype(np.float16), open('/content/Datas/[X_train].p', 'wb'))
pickle.dump(y_train, open('/content/Datas/[y_train].p', 'wb'))
pickle.dump(X_test.astype(np.float16), open('/content/Datas/[X_test].p', 'wb'))
pickle.dump(y_test, open('/content/Datas/[y_test].p', 'wb'))

# %%
import os
from glob import glob
import pickle
import numpy as np

### Plot imports ###
from IPython.display import Image
import matplotlib.pyplot as plt

### Time Distributed ConvNet imports ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, TimeDistributed, concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import LabelEncoder

### Warning ###
import warnings
warnings.filterwarnings('ignore')

# %%
X_train = pickle.load(open('/content/Datas/[X_train].p', 'rb'))
y_train = pickle.load(open('/content/Datas/[y_train].p', 'rb'))
y_test = pickle.load(open('/content/Datas/[y_test].p', 'rb'))
X_test = pickle.load(open('/content/Datas/[X_test].p', 'rb'))

# %%
lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(np.ravel(y_train)))
y_test = np_utils.to_categorical(lb.transform(np.ravel(y_test)))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , X_train.shape[2], X_train.shape[3], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] , X_test.shape[2], X_test.shape[3], 1)

# %%
X_test.shape
# Out:
# (80, 5, 128, 128, 1)

# %%
K.clear_session()

# Define two sets of inputs: MFCC and FBANK
input_y = Input(shape=X_train.shape[1:], name='Input_MELSPECT')

## First LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_1_MELSPECT')(input_y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_1_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_1_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'), name='MaxPool_1_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_1_MELSPECT')(y)     

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_2_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_2_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_2_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_2_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_2_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_3_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_3_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_3_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_3_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_3_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_4_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_4_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_4_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_4_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_4_MELSPECT')(y)  

## Flat
y = TimeDistributed(Flatten(), name='Flat_MELSPECT')(y)                      
                               
# Apply 2 LSTM layer and one FC
y = LSTM(256, return_sequences=False, dropout=0.2, name='LSTM_1')(y)
y = Dense(y_train.shape[1], activation='softmax', name='FC')(y)

# Build final model
model = Model(inputs=input_y, outputs=y)

# Plot model graph
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
Image(retina=True, filename='model.png')

# %%
# Compile model
model.compile(optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.8), loss='categorical_crossentropy', metrics=['accuracy'])

# Save best model
best_model_save = ModelCheckpoint('/content/drive/MyDrive/Model/[CNN-LSTM]Model.hdf5', save_best_only=True, monitor='val_acc', mode='max')

# Early stopping
early_stopping = EarlyStopping(monitor='val_acc', patience=30, verbose=1, mode='max')

# Fit model
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping, best_model_save])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 41s 376ms/step - loss: 1.3993 - accuracy: 0.2750 - val_loss: 1.4896 - val_accuracy: 0.2250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/100
# 15/15 [==============================] - 5s 308ms/step - loss: 1.3371 - accuracy: 0.3438 - val_loss: 1.5124 - val_accuracy: 0.2875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/100
# 15/15 [==============================] - 5s 309ms/step - loss: 1.2653 - accuracy: 0.4260 - val_loss: 1.3682 - val_accuracy: 0.4750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/100
# 15/15 [==============================] - 5s 310ms/step - loss: 1.1240 - accuracy: 0.5271 - val_loss: 1.5186 - val_accuracy: 0.2750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/100
# 15/15 [==============================] - 5s 309ms/step - loss: 0.9888 - accuracy: 0.5896 - val_loss: 1.2519 - val_accuracy: 0.4250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/100
# 15/15 [==============================] - 5s 310ms/step - loss: 0.8726 - accuracy: 0.6156 - val_loss: 1.3089 - val_accuracy: 0.4625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.8232 - accuracy: 0.6417 - val_loss: 1.2431 - val_accuracy: 0.4625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/100
# 15/15 [==============================] - 5s 310ms/step - loss: 0.7860 - accuracy: 0.6573 - val_loss: 1.0568 - val_accuracy: 0.6375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.7385 - accuracy: 0.6698 - val_loss: 1.1150 - val_accuracy: 0.5500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/100
# 15/15 [==============================] - 5s 310ms/step - loss: 0.7270 - accuracy: 0.6938 - val_loss: 1.1826 - val_accuracy: 0.6250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/100
# 15/15 [==============================] - 5s 308ms/step - loss: 0.7021 - accuracy: 0.6896 - val_loss: 0.6983 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/100
# 15/15 [==============================] - 5s 310ms/step - loss: 0.7047 - accuracy: 0.7010 - val_loss: 0.9090 - val_accuracy: 0.6250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.6238 - accuracy: 0.7312 - val_loss: 0.7258 - val_accuracy: 0.6875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.6382 - accuracy: 0.7271 - val_loss: 0.9433 - val_accuracy: 0.5750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.6051 - accuracy: 0.7375 - val_loss: 0.8968 - val_accuracy: 0.6625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5968 - accuracy: 0.7458 - val_loss: 3.5545 - val_accuracy: 0.2625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.6171 - accuracy: 0.7271 - val_loss: 1.1814 - val_accuracy: 0.5625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.6004 - accuracy: 0.7333 - val_loss: 0.9669 - val_accuracy: 0.6250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5846 - accuracy: 0.7542 - val_loss: 0.6922 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5931 - accuracy: 0.7385 - val_loss: 0.7430 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.5381 - accuracy: 0.7688 - val_loss: 1.0255 - val_accuracy: 0.6125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.5385 - accuracy: 0.7604 - val_loss: 1.0916 - val_accuracy: 0.6000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5405 - accuracy: 0.7698 - val_loss: 0.7440 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.5067 - accuracy: 0.7833 - val_loss: 0.8434 - val_accuracy: 0.6625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5622 - accuracy: 0.7677 - val_loss: 1.4174 - val_accuracy: 0.5750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5169 - accuracy: 0.7854 - val_loss: 1.2373 - val_accuracy: 0.6125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5182 - accuracy: 0.7750 - val_loss: 1.6361 - val_accuracy: 0.5625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.5113 - accuracy: 0.7635 - val_loss: 0.8100 - val_accuracy: 0.6750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.5096 - accuracy: 0.7833 - val_loss: 0.6458 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.4937 - accuracy: 0.7812 - val_loss: 1.4160 - val_accuracy: 0.5875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4770 - accuracy: 0.7906 - val_loss: 1.1297 - val_accuracy: 0.6000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 15/15 [==============================] - 5s 310ms/step - loss: 0.4617 - accuracy: 0.7990 - val_loss: 1.1312 - val_accuracy: 0.6125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4766 - accuracy: 0.8073 - val_loss: 1.0038 - val_accuracy: 0.6375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.4575 - accuracy: 0.8208 - val_loss: 1.0006 - val_accuracy: 0.6375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4333 - accuracy: 0.8083 - val_loss: 1.1497 - val_accuracy: 0.6000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.4468 - accuracy: 0.7990 - val_loss: 1.7526 - val_accuracy: 0.4750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4544 - accuracy: 0.7969 - val_loss: 0.6568 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4304 - accuracy: 0.8198 - val_loss: 0.6443 - val_accuracy: 0.7625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4374 - accuracy: 0.8115 - val_loss: 0.7505 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.4190 - accuracy: 0.8333 - val_loss: 2.0385 - val_accuracy: 0.5250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.4825 - accuracy: 0.7792 - val_loss: 0.7648 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4152 - accuracy: 0.8323 - val_loss: 0.9497 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.3975 - accuracy: 0.8365 - val_loss: 0.8085 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.3798 - accuracy: 0.8417 - val_loss: 0.8179 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.4196 - accuracy: 0.8083 - val_loss: 1.3924 - val_accuracy: 0.6250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.4135 - accuracy: 0.8250 - val_loss: 1.2176 - val_accuracy: 0.6875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.4088 - accuracy: 0.8323 - val_loss: 1.8947 - val_accuracy: 0.5625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.4147 - accuracy: 0.8208 - val_loss: 1.3402 - val_accuracy: 0.6375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.4050 - accuracy: 0.8250 - val_loss: 0.6954 - val_accuracy: 0.7750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.3809 - accuracy: 0.8469 - val_loss: 0.8963 - val_accuracy: 0.6875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 51/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.3524 - accuracy: 0.8510 - val_loss: 0.7321 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 52/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.3795 - accuracy: 0.8479 - val_loss: 0.8014 - val_accuracy: 0.7750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 53/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.3828 - accuracy: 0.8406 - val_loss: 1.9124 - val_accuracy: 0.6000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 54/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.3335 - accuracy: 0.8604 - val_loss: 0.8013 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 55/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.3909 - accuracy: 0.8271 - val_loss: 1.2962 - val_accuracy: 0.6375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 56/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.3494 - accuracy: 0.8490 - val_loss: 0.9104 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 57/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.3065 - accuracy: 0.8708 - val_loss: 0.8177 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 58/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.3090 - accuracy: 0.8760 - val_loss: 0.8792 - val_accuracy: 0.7750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 59/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2982 - accuracy: 0.8771 - val_loss: 0.8124 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 60/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.2918 - accuracy: 0.8823 - val_loss: 1.1109 - val_accuracy: 0.7000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 61/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.3136 - accuracy: 0.8719 - val_loss: 0.8779 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 62/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2882 - accuracy: 0.8948 - val_loss: 0.7729 - val_accuracy: 0.7625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 63/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2960 - accuracy: 0.8844 - val_loss: 0.8414 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 64/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2666 - accuracy: 0.8927 - val_loss: 0.7538 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 65/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2842 - accuracy: 0.8865 - val_loss: 0.8696 - val_accuracy: 0.7875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 66/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2856 - accuracy: 0.8896 - val_loss: 0.8952 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 67/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2350 - accuracy: 0.9135 - val_loss: 0.8727 - val_accuracy: 0.7625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 68/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2604 - accuracy: 0.8844 - val_loss: 0.9474 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 69/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2818 - accuracy: 0.8990 - val_loss: 0.9776 - val_accuracy: 0.6875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 70/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2732 - accuracy: 0.8844 - val_loss: 0.8012 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 71/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2541 - accuracy: 0.9021 - val_loss: 1.0223 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 72/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2020 - accuracy: 0.9281 - val_loss: 0.9815 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 73/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2173 - accuracy: 0.9062 - val_loss: 0.8802 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 74/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.2899 - accuracy: 0.8771 - val_loss: 1.2266 - val_accuracy: 0.6625
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 75/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2441 - accuracy: 0.9135 - val_loss: 0.9143 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 76/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2173 - accuracy: 0.9052 - val_loss: 0.9985 - val_accuracy: 0.7000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 77/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.2268 - accuracy: 0.9125 - val_loss: 0.9728 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 78/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2124 - accuracy: 0.9250 - val_loss: 0.9664 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 79/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2037 - accuracy: 0.9177 - val_loss: 1.0327 - val_accuracy: 0.7000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 80/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2372 - accuracy: 0.9052 - val_loss: 0.9657 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 81/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1741 - accuracy: 0.9375 - val_loss: 0.8850 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 82/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.2065 - accuracy: 0.9219 - val_loss: 1.1423 - val_accuracy: 0.7000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 83/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1826 - accuracy: 0.9229 - val_loss: 0.9825 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 84/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1801 - accuracy: 0.9365 - val_loss: 0.9273 - val_accuracy: 0.7000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 85/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1733 - accuracy: 0.9385 - val_loss: 0.9239 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 86/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1370 - accuracy: 0.9542 - val_loss: 0.9268 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 87/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.1619 - accuracy: 0.9396 - val_loss: 1.0971 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 88/100
# 15/15 [==============================] - 5s 312ms/step - loss: 0.1982 - accuracy: 0.9208 - val_loss: 1.0146 - val_accuracy: 0.7000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 89/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.1921 - accuracy: 0.9229 - val_loss: 1.1188 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 90/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.1594 - accuracy: 0.9375 - val_loss: 0.9366 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 91/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.1609 - accuracy: 0.9375 - val_loss: 0.9520 - val_accuracy: 0.7500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 92/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.1748 - accuracy: 0.9344 - val_loss: 1.1306 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 93/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1621 - accuracy: 0.9354 - val_loss: 0.9957 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 94/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.1275 - accuracy: 0.9531 - val_loss: 1.0496 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 95/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.1479 - accuracy: 0.9438 - val_loss: 0.8088 - val_accuracy: 0.7375
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 96/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.1505 - accuracy: 0.9438 - val_loss: 1.0407 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 97/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1349 - accuracy: 0.9458 - val_loss: 1.1449 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 98/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.1416 - accuracy: 0.9469 - val_loss: 1.0941 - val_accuracy: 0.6875
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 99/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1139 - accuracy: 0.9573 - val_loss: 0.9621 - val_accuracy: 0.7125
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 100/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.1237 - accuracy: 0.9573 - val_loss: 1.0388 - val_accuracy: 0.7250
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.

# %%
model.load_weights('/content/drive/MyDrive/Model/[CNN-LSTM]W.h5')

# %%
X_test.shape
# Out:
# (80, 5, 128, 128, 1)

# %%
model.evaluate(X_test,y_test,batch_size=32)
# Out:
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2561 - accuracy: 0.9375
# [0.2561042904853821, 0.9375]

# %%
Y_pred=model.predict(X_test)

# %%
np.argmax(Y_pred,axis=1)
# Out:
# array([0, 0, 3, 0, 3, 3, 2, 3, 0, 1, 1, 2, 3, 3, 1, 3, 3, 2, 0, 2, 3, 3,
#        2, 0, 3, 2, 1, 0, 0, 1, 2, 1, 0, 3, 0, 3, 1, 2, 1, 1, 2, 3, 3, 3,
#        3, 2, 1, 1, 3, 1, 3, 2, 2, 1, 2, 3, 0, 1, 3, 1, 1, 0, 0, 3, 1, 3,
#        2, 0, 2, 3, 2, 1, 3, 1, 2, 0, 0, 2, 1, 0])

# %%
np.argmax(y_test,axis=1)
# Out:
# array([0, 0, 3, 0, 3, 3, 2, 3, 0, 1, 3, 2, 3, 3, 1, 3, 0, 2, 0, 2, 3, 3,
#        2, 0, 3, 2, 1, 0, 0, 1, 2, 1, 0, 3, 0, 1, 1, 2, 1, 1, 2, 3, 3, 3,
#        3, 2, 1, 1, 3, 1, 3, 2, 2, 3, 2, 3, 0, 1, 3, 1, 1, 0, 0, 3, 1, 3,
#        2, 0, 2, 3, 2, 1, 3, 3, 2, 0, 0, 2, 1, 0])

# %%
 def predict_emotion_from_file(model, filename, chunk_step=16000, chunk_size=49100, predict_proba=False, sample_rate=16000):
        # Read audio file
        emotion1={0:'Angry',1:'Happy',2:'Sad',3:'Neutral'}
        y, sr = librosa.core.load(filename, sr=sample_rate, offset=0.5)
        win_ts = 128
        hop_ts = 64
        if len(y) < max_pad_len:    
          y_padded = np.zeros(max_pad_len)
          y_padded[:len(y)] = y
          y = y_padded
        elif len(y) > max_pad_len:
          y = np.asarray(y[:max_pad_len])
        # Split audio signals into chunks
        chunks = frame(y.reshape(1, 1, -1), chunk_step, chunk_size)
        # Reshape chunks
        chunks = chunks.reshape(chunks.shape[1],chunks.shape[-1])

        # Z-normalization
        y = np.asarray(list(map(zscore, chunks)))

        # Compute mel spectrogram
        mel_spect = np.asarray(list(map(mel_spectrogram, y)))

        # Time distributed Framing
        mel_spect_ts = frame(mel_spect,hop_ts,win_ts)
        print(mel_spect_ts.shape)
        # Build X for time distributed CNN
        X = mel_spect_ts.reshape(mel_spect_ts.shape[0],
                                    mel_spect_ts.shape[1],
                                    mel_spect_ts.shape[2],
                                    mel_spect_ts.shape[3],
                                    1)
        # Predict emotion
        if predict_proba is True:
            predict = model.predict(X)
        else:
            predict = np.argmax(model.predict(X), axis=1)
            print(predict)
            predict = [emotion1.get(emotion) for emotion in predict]



        return predict

# %%
filename='/content/test1.wav'
predict=predict_emotion_from_file(model, filename, chunk_step=16000, chunk_size=49100, predict_proba=False, sample_rate=16000)
# Out:
# (1, 5, 128, 128)
# [2]

# %%
predict
# Out:
# ['Sad']

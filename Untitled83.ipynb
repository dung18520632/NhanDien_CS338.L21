# %% [markdown]
# <a href="https://colab.research.google.com/github/dung18520632/NhanDien_CS338.L21/blob/main/Untitled83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/Data.zip

# %%
import scipy.io.wavfile
import numpy as np
import sys
import glob 
import librosa
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
mylist= os.listdir('/content/Data')
file_emotion=[]
for i in mylist:
  file_emotion.append(os.listdir('Data/'+i+"/"))
file_emotion=np.asarray(file_emotion).ravel()

# %%
feeling_list=[]
#print(file_emotion)
for item in file_emotion:
    if item[0:1]=='0' :
        feeling_list.append('Angry')
    elif item[0:1]=='1':
        feeling_list.append('Happy')
    elif item[0:1]=='3':
        feeling_list.append('Neutral')
    else:
        feeling_list.append('Sad')
labels = feeling_list

# %%
import itertools
import numpy as np
from scipy.stats import zscore
from IPython.display import Audio

# %%
sample_rate = 16000
max_pad_len = 55000
signal = []
for index,f in enumerate(file_emotion):
    m=""
    if f[0:1]=='0' :
        m='Angry/'
    elif f[0:1]=='1':
        m='Happy/'
    elif f[0:1]=='3':
        m='Neutral/'
    else:
        m='Sad/'
    y, sample_rate = librosa.load('Data/'+m+f,sr=sample_rate,offset=0.5)
    y=zscore(y)
    if len(y) < max_pad_len:    
         y_padded = np.zeros(max_pad_len)
         y_padded[:len(y)] = y
         y = y_padded
    elif len(y) > max_pad_len:
         y = np.asarray(y[:max_pad_len])
    signal.append(y)
    if (index % 100 == 0):
            print("Import Data: RUNNING ... {} files".format(index))
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Import Data: RUNNING ... 200 files
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Import Data: RUNNING ... 300 files
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
np.array(signal).shape
# Out:
# (400, 55000)

# %%
random_idx = np.random.randint(len(labels))
random_label = labels[random_idx]
random_signal = signal[random_idx]
random_filename = file_emotion[random_idx]

# Plot signal wave
plt.figure(figsize=(10,5))
plt.plot(np.arange(len(random_signal))/float(sample_rate), random_signal)
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' with label {}".format(random_filename, random_label), fontsize=18)
plt.show()

# Play audio file
print("Audio file '{}':".format(random_filename))
Audio(random_signal, rate=sample_rate)
# Out:
# Audio file '3_46.wav':
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
nb_augmented = 2

# Function to add noise to a signals with a desired Signal Noise ratio (SNR)
def noisy_signal(signal, snr_low=15, snr_high=30, nb_augmented=2):
    
    # Signal length
    signal_len = len(signal)

    # Generate White noise
    noise = np.random.normal(size=(nb_augmented, signal_len))
    
    # Compute signal and noise power
    s_power = np.sum((signal / (2.0 ** 15)) ** 2) / signal_len
    n_power = np.sum((noise / (2.0 ** 15)) ** 2, axis=1) / signal_len
    
    # Random SNR: Uniform [15, 30]
    snr = np.random.randint(snr_low, snr_high)
    
    # Compute K coeff for each noise
    K = np.sqrt((s_power / n_power) * 10 ** (- snr / 10))
    K = np.ones((signal_len, nb_augmented)) * K
    
    # Generate noisy signal
    return signal + K.T * noise

# %%
print("Data Augmentation: START")
augmented_signal = list(map(noisy_signal, signal))
print("Data Augmentation: END!")
# Out:
# Data Augmentation: START
# Data Augmentation: END!

# %%
import os
from glob import glob
import pickle
import itertools
import numpy as np
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

### Graph imports ###
import matplotlib.pyplot as plt
from PIL import Image

### Audio import ###
import librosa
import IPython
from IPython.display import Audio

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(np.arange(len(random_signal))/float(sample_rate), random_signal)
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' ".format(random_filename), fontsize=18)

# Plot signal wave with noise
plt.subplot(1,2,2)
plt.plot(np.arange(len(random_signal))/float(sample_rate), augmented_signal[random_idx][0])
plt.xlim((np.arange(len(random_signal))/float(sample_rate))[0], (np.arange(len(random_signal))/float(sample_rate))[-1])
plt.xlabel('Time (s)', fontsize=16)
plt.ylabel('Amplitude (dB)', fontsize=16)
plt.title("Signal wave of file '{}' with Noise".format(random_filename), fontsize=18)
plt.show()

# Play audio file
print("Audio file '{}':".format(random_filename))
IPython.display.display(Audio(random_signal, rate=sample_rate))

# Play same audio file with noise
print("Audio file '{}' with noise:".format(random_filename))
IPython.display.display(Audio(augmented_signal[random_idx][0], rate=sample_rate))
# Out:
# Audio file '3_46.wav':
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio file '3_46.wav' with noise:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def mel_spectrogram(y, sr=16000, n_fft=512, win_length=256, hop_length=128, window='hamming', n_mels=128, fmax=4000):
    
    # Compute spectogram
    mel_spect = np.abs(librosa.stft(y, n_fft=n_fft, window=window, win_length=win_length, hop_length=hop_length)) ** 2
    
    # Compute mel spectrogram
    mel_spect = librosa.feature.melspectrogram(S=mel_spect, sr=sr, n_mels=n_mels, fmax=fmax)
    
    # Compute log-mel spectrogram
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    
    return mel_spect

# %%
# Start feature extraction
print("Feature extraction: START")

# Compute spectogram for all audio file
mel_spect = np.asarray(list(map(mel_spectrogram, signal)))
augmented_mel_spect = [np.asarray(list(map(mel_spectrogram, augmented_signal[i]))) for i in range(len(augmented_signal))]

# Stop feature extraction
print("Feature extraction: END!")
# Out:
# Feature extraction: START
# Feature extraction: END!

# %%
# Plot one random Spectogram 
plt.figure(figsize=(20, 10))
plt.imshow(mel_spect[np.random.randint(len(mel_spect))], origin='lower', aspect='auto', cmap='viridis')
plt.title('Log-Mel Spectrogram of an audio file', fontsize=26)
plt.tight_layout()
plt.show()

# %%
MEL_SPECT_train, MEL_SPECT_test, AUG_MEL_SPECT_train, AUG_MEL_SPECT_test, label_train, label_test = train_test_split(mel_spect, augmented_mel_spect, labels, test_size=0.2,random_state=42)

# Build augmented labels and train
aug_label_train = np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))
AUG_MEL_SPECT_train = np.asarray(list(itertools.chain.from_iterable(AUG_MEL_SPECT_train)))

# Concatenate original and augmented
X_train = np.concatenate((MEL_SPECT_train, AUG_MEL_SPECT_train))
y_train = np.concatenate((label_train, aug_label_train))

# Build test set
X_test = MEL_SPECT_test
y_test = label_test

# Delete
# del MEL_SPECT_train, AUG_MEL_SPECT_train, label_train, aug_label_train, AUG_MEL_SPECT_test, MEL_SPECT_test, label_test
# del mel_spect, augmented_mel_spect, labels

# %%
np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))

# %%
# Time distributed parameters
win_ts = 128
hop_ts = 64

# Split spectrogram into frames
def frame(x, win_step=128, win_size=64):
    nb_frames = 1 + int((x.shape[2] - win_size) / win_step)
    frames = np.zeros((x.shape[0], nb_frames, x.shape[1], win_size)).astype(np.float32)
    for t in range(nb_frames):
        frames[:,t,:,:] = np.copy(x[:,:,(t * win_step):(t * win_step + win_size)]).astype(np.float32)
    return frames

# Frame for TimeDistributed model
X_train = frame(X_train, hop_ts, win_ts)
X_test = frame(X_test, hop_ts, win_ts)

# %%
X_train.shape

# %%
# Save Train and test set
pickle.dump(X_train.astype(np.float16), open('/content/Datas/[X_train].p', 'wb'))
pickle.dump(y_train, open('/content/Datas/[y_train].p', 'wb'))
pickle.dump(X_test.astype(np.float16), open('/content/Datas/[X_test].p', 'wb'))
pickle.dump(y_test, open('/content/Datas/[y_test].p', 'wb'))

# %%
import os
from glob import glob
import pickle
import numpy as np

### Plot imports ###
from IPython.display import Image
import matplotlib.pyplot as plt

### Time Distributed ConvNet imports ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, TimeDistributed, concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import LabelEncoder

### Warning ###
import warnings
warnings.filterwarnings('ignore')

# %%
X_train = pickle.load(open('/content/Datas/[X_train].p', 'rb'))
y_train = pickle.load(open('/content/Datas/[y_train].p', 'rb'))
y_test = pickle.load(open('/content/Datas/[y_test].p', 'rb'))
X_test = pickle.load(open('/content/Datas/[X_test].p', 'rb'))

# %%
lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(np.ravel(y_train)))
y_test = np_utils.to_categorical(lb.transform(np.ravel(y_test)))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , X_train.shape[2], X_train.shape[3], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] , X_test.shape[2], X_test.shape[3], 1)

# %%
K.clear_session()

# Define two sets of inputs: MFCC and FBANK
input_y = Input(shape=X_train.shape[1:], name='Input_MELSPECT')

## First LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_1_MELSPECT')(input_y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_1_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_1_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'), name='MaxPool_1_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_1_MELSPECT')(y)     

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_2_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_2_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_2_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_2_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_2_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_3_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_3_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_3_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_3_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_3_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_4_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_4_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_4_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_4_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_4_MELSPECT')(y)  

## Flat
y = TimeDistributed(Flatten(), name='Flat_MELSPECT')(y)                      
                               
# Apply 2 LSTM layer and one FC
y = LSTM(256, return_sequences=False, dropout=0.2, name='LSTM_1')(y)
y = Dense(y_train.shape[1], activation='softmax', name='FC')(y)

# Build final model
model = Model(inputs=input_y, outputs=y)

# Plot model graph
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
Image(retina=True, filename='model.png')

# %%
# Compile model
model.compile(optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.8), loss='categorical_crossentropy', metrics=['accuracy'])

# Save best model
best_model_save = ModelCheckpoint('/content/Datas/best.hdf5', save_best_only=True, monitor='val_accuracy', mode='max')


# Early stopping
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, verbose=1, mode='max')

# Fit model
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping, best_model_save])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 7s 351ms/step - loss: 1.4178 - accuracy: 0.2552 - val_loss: 1.4690 - val_accuracy: 0.2250
# Epoch 2/100
# 15/15 [==============================] - 5s 311ms/step - loss: 1.3439 - accuracy: 0.3500 - val_loss: 1.5712 - val_accuracy: 0.3875
# Epoch 3/100
# 15/15 [==============================] - 5s 311ms/step - loss: 1.2451 - accuracy: 0.4469 - val_loss: 1.5821 - val_accuracy: 0.3250
# Epoch 4/100
# 15/15 [==============================] - 5s 311ms/step - loss: 1.1002 - accuracy: 0.5490 - val_loss: 1.3094 - val_accuracy: 0.4125
# Epoch 5/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.9763 - accuracy: 0.5771 - val_loss: 1.5534 - val_accuracy: 0.3250
# Epoch 6/100
# 15/15 [==============================] - 5s 311ms/step - loss: 0.8599 - accuracy: 0.6198 - val_loss: 1.4971 - val_accuracy: 0.3250
# Epoch 7/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.8206 - accuracy: 0.6604 - val_loss: 0.9619 - val_accuracy: 0.5750
# Epoch 8/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.7913 - accuracy: 0.6740 - val_loss: 2.2641 - val_accuracy: 0.2500
# Epoch 9/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.7075 - accuracy: 0.6958 - val_loss: 0.9491 - val_accuracy: 0.5375
# Epoch 10/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.7028 - accuracy: 0.7042 - val_loss: 0.8099 - val_accuracy: 0.6250
# Epoch 11/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.6682 - accuracy: 0.7260 - val_loss: 0.8442 - val_accuracy: 0.6000
# Epoch 12/100
# 15/15 [==============================] - 5s 313ms/step - loss: 0.6456 - accuracy: 0.7396 - val_loss: 0.7945 - val_accuracy: 0.6250
# Epoch 13/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.6500 - accuracy: 0.7219 - val_loss: 0.7948 - val_accuracy: 0.6375
# Epoch 14/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.6289 - accuracy: 0.7354 - val_loss: 2.2091 - val_accuracy: 0.3250
# Epoch 15/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.6802 - accuracy: 0.6969 - val_loss: 0.8681 - val_accuracy: 0.6125
# Epoch 16/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.6160 - accuracy: 0.7229 - val_loss: 0.8119 - val_accuracy: 0.6375
# Epoch 17/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.5907 - accuracy: 0.7469 - val_loss: 1.3126 - val_accuracy: 0.4625
# Epoch 18/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.5938 - accuracy: 0.7469 - val_loss: 1.1141 - val_accuracy: 0.5875
# Epoch 19/100
# 15/15 [==============================] - 5s 314ms/step - loss: 0.6018 - accuracy: 0.7365 - val_loss: 2.6896 - val_accuracy: 0.3875
# Epoch 20/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.5674 - accuracy: 0.7542 - val_loss: 2.2899 - val_accuracy: 0.4500
# Epoch 21/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.5534 - accuracy: 0.7563 - val_loss: 0.8482 - val_accuracy: 0.6375
# Epoch 22/100
# 15/15 [==============================] - 5s 316ms/step - loss: 0.5575 - accuracy: 0.7563 - val_loss: 1.6647 - val_accuracy: 0.5250
# Epoch 23/100
# 15/15 [==============================] - 5s 317ms/step - loss: 0.5480 - accuracy: 0.7635 - val_loss: 0.7416 - val_accuracy: 0.6500
# Epoch 24/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.5235 - accuracy: 0.7708 - val_loss: 1.8856 - val_accuracy: 0.3750
# Epoch 25/100
# 15/15 [==============================] - 5s 315ms/step - loss: 0.5290 - accuracy: 0.7771 - val_loss: 0.8958 - val_accuracy: 0.6250
# Epoch 26/100
# 15/15 [==============================] - 5s 317ms/step - loss: 0.5153 - accuracy: 0.7823 - val_loss: 0.8935 - val_accuracy: 0.5875
# Epoch 27/100
# 15/15 [==============================] - 5s 316ms/step - loss: 0.5100 - accuracy: 0.7792 - val_loss: 1.4609 - val_accuracy: 0.4625
# Epoch 28/100
# 15/15 [==============================] - 5s 317ms/step - loss: 0.4987 - accuracy: 0.7917 - val_loss: 0.8775 - val_accuracy: 0.5750
# Epoch 29/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.5287 - accuracy: 0.7656 - val_loss: 1.0587 - val_accuracy: 0.5250
# Epoch 30/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.5210 - accuracy: 0.7750 - val_loss: 0.9439 - val_accuracy: 0.5750
# Epoch 31/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.4965 - accuracy: 0.7844 - val_loss: 1.2662 - val_accuracy: 0.5250
# Epoch 32/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.4901 - accuracy: 0.7958 - val_loss: 0.7326 - val_accuracy: 0.7125
# Epoch 33/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.4861 - accuracy: 0.7854 - val_loss: 0.7008 - val_accuracy: 0.7125
# Epoch 34/100
# 15/15 [==============================] - 5s 317ms/step - loss: 0.4539 - accuracy: 0.8062 - val_loss: 1.0840 - val_accuracy: 0.6375
# Epoch 35/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.4504 - accuracy: 0.8052 - val_loss: 1.0056 - val_accuracy: 0.6375
# Epoch 36/100
# 15/15 [==============================] - 5s 317ms/step - loss: 0.4494 - accuracy: 0.7990 - val_loss: 0.7864 - val_accuracy: 0.7375
# Epoch 37/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.4394 - accuracy: 0.8021 - val_loss: 1.1210 - val_accuracy: 0.6625
# Epoch 38/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.4456 - accuracy: 0.8104 - val_loss: 1.9772 - val_accuracy: 0.3875
# Epoch 39/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.4340 - accuracy: 0.8177 - val_loss: 0.5372 - val_accuracy: 0.7500
# Epoch 40/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.4379 - accuracy: 0.8062 - val_loss: 0.7901 - val_accuracy: 0.6625
# Epoch 41/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.4337 - accuracy: 0.8115 - val_loss: 0.8244 - val_accuracy: 0.6375
# Epoch 42/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.4599 - accuracy: 0.7958 - val_loss: 0.9111 - val_accuracy: 0.6375
# Epoch 43/100
# 15/15 [==============================] - 5s 318ms/step - loss: 0.4236 - accuracy: 0.8281 - val_loss: 1.0051 - val_accuracy: 0.5875
# Epoch 44/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.4180 - accuracy: 0.8094 - val_loss: 0.5687 - val_accuracy: 0.7625
# Epoch 45/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.3925 - accuracy: 0.8208 - val_loss: 0.7209 - val_accuracy: 0.6875
# Epoch 46/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3975 - accuracy: 0.8250 - val_loss: 0.9513 - val_accuracy: 0.6625
# Epoch 47/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3888 - accuracy: 0.8219 - val_loss: 1.7535 - val_accuracy: 0.5750
# Epoch 48/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.3824 - accuracy: 0.8354 - val_loss: 0.7313 - val_accuracy: 0.7000
# Epoch 49/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3731 - accuracy: 0.8406 - val_loss: 0.8801 - val_accuracy: 0.6375
# Epoch 50/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.3503 - accuracy: 0.8490 - val_loss: 1.0796 - val_accuracy: 0.6500
# Epoch 51/100
# 15/15 [==============================] - 5s 319ms/step - loss: 0.3623 - accuracy: 0.8375 - val_loss: 0.8453 - val_accuracy: 0.7250
# Epoch 52/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3762 - accuracy: 0.8385 - val_loss: 0.8005 - val_accuracy: 0.7125
# Epoch 53/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3514 - accuracy: 0.8479 - val_loss: 0.5507 - val_accuracy: 0.7875
# Epoch 54/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3416 - accuracy: 0.8510 - val_loss: 1.3512 - val_accuracy: 0.6000
# Epoch 55/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.3148 - accuracy: 0.8625 - val_loss: 0.8068 - val_accuracy: 0.7250
# Epoch 56/100
# 15/15 [==============================] - 5s 322ms/step - loss: 0.3268 - accuracy: 0.8594 - val_loss: 0.9749 - val_accuracy: 0.7000
# Epoch 57/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3012 - accuracy: 0.8823 - val_loss: 0.7624 - val_accuracy: 0.6500
# Epoch 58/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3209 - accuracy: 0.8646 - val_loss: 0.7949 - val_accuracy: 0.6750
# Epoch 59/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.3134 - accuracy: 0.8729 - val_loss: 1.5580 - val_accuracy: 0.4875
# Epoch 60/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.3052 - accuracy: 0.8750 - val_loss: 0.7616 - val_accuracy: 0.6875
# Epoch 61/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3028 - accuracy: 0.8719 - val_loss: 0.6784 - val_accuracy: 0.7375
# Epoch 62/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.2637 - accuracy: 0.8854 - val_loss: 0.8830 - val_accuracy: 0.6875
# Epoch 63/100
# 15/15 [==============================] - 5s 322ms/step - loss: 0.2849 - accuracy: 0.8854 - val_loss: 0.8299 - val_accuracy: 0.6750
# Epoch 64/100
# 15/15 [==============================] - 5s 323ms/step - loss: 0.2790 - accuracy: 0.8885 - val_loss: 0.8452 - val_accuracy: 0.6625
# Epoch 65/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.3095 - accuracy: 0.8833 - val_loss: 0.7772 - val_accuracy: 0.6875
# Epoch 66/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.2594 - accuracy: 0.8906 - val_loss: 0.7715 - val_accuracy: 0.7125
# Epoch 67/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.3060 - accuracy: 0.8625 - val_loss: 1.1989 - val_accuracy: 0.6250
# Epoch 68/100
# 15/15 [==============================] - 5s 322ms/step - loss: 0.2647 - accuracy: 0.8844 - val_loss: 0.6638 - val_accuracy: 0.7375
# Epoch 69/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.2512 - accuracy: 0.8927 - val_loss: 0.7905 - val_accuracy: 0.7125
# Epoch 70/100
# 15/15 [==============================] - 5s 322ms/step - loss: 0.2292 - accuracy: 0.9115 - val_loss: 0.9881 - val_accuracy: 0.7000
# Epoch 71/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.2262 - accuracy: 0.9125 - val_loss: 0.7639 - val_accuracy: 0.7250
# Epoch 72/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.2422 - accuracy: 0.9104 - val_loss: 1.1195 - val_accuracy: 0.6250
# Epoch 73/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.2228 - accuracy: 0.9094 - val_loss: 1.2925 - val_accuracy: 0.7000
# Epoch 74/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.2421 - accuracy: 0.9052 - val_loss: 0.7164 - val_accuracy: 0.7250
# Epoch 75/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.1941 - accuracy: 0.9187 - val_loss: 0.6853 - val_accuracy: 0.7500
# Epoch 76/100
# 15/15 [==============================] - 5s 322ms/step - loss: 0.2294 - accuracy: 0.9104 - val_loss: 1.0266 - val_accuracy: 0.6750
# Epoch 77/100
# 15/15 [==============================] - 5s 322ms/step - loss: 0.2228 - accuracy: 0.9083 - val_loss: 1.2041 - val_accuracy: 0.6625
# Epoch 78/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.2513 - accuracy: 0.8969 - val_loss: 1.0168 - val_accuracy: 0.7250
# Epoch 79/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.2306 - accuracy: 0.9125 - val_loss: 1.7659 - val_accuracy: 0.6250
# Epoch 80/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.2175 - accuracy: 0.9187 - val_loss: 1.4702 - val_accuracy: 0.5625
# Epoch 81/100
# 15/15 [==============================] - 5s 322ms/step - loss: 0.1835 - accuracy: 0.9344 - val_loss: 0.8951 - val_accuracy: 0.7250
# Epoch 82/100
# 15/15 [==============================] - 5s 320ms/step - loss: 0.1753 - accuracy: 0.9344 - val_loss: 0.6857 - val_accuracy: 0.7500
# Epoch 83/100
# 15/15 [==============================] - 5s 321ms/step - loss: 0.1944 - accuracy: 0.9198 - val_loss: 1.0462 - val_accuracy: 0.7000
# Epoch 00083: early stopping

# %%
model.load_weights('/content/drive/MyDrive/Model_55000/best.hdf5')

# %%
model.evaluate(X_test,y_test,batch_size=32)
# Out:
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0462 - accuracy: 0.7000
# [1.046217918395996, 0.699999988079071]

# %%
Y_pred=model.predict(X_test)
Y_pred=np.argmax(Y_pred,axis=1)
y_true=np.argmax(y_test,axis=1)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.89      0.73        18
#            1       0.78      0.27      0.40        26
#            2       1.00      0.94      0.97        18
#            3       0.57      0.89      0.70        18
#
#     accuracy                           0.70        80
#    macro avg       0.74      0.75      0.70        80
# weighted avg       0.74      0.70      0.67        80

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
Y_pred=model.predict(X_test)
Y_pred=np.argmax(Y_pred,axis=1)
y_true=np.argmax(y_test,axis=1)
cm = confusion_matrix(y_true,Y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                colorbar=True,
                                show_absolute=True,
                                show_normed=True,
                                )
plt.show()

# %%
 def predict_emotion_from_file(model, filename, chunk_step=16000, chunk_size=49100, predict_proba=False, sample_rate=16000):
        # Read audio file
        emotion1={0:'Angry',1:'Happy',2:'Sad',3:'Neutral'}
        y, sr = librosa.core.load(filename, sr=sample_rate, offset=0.5)
        win_ts = 128
        hop_ts = 64
        if len(y) < max_pad_len:    
          y_padded = np.zeros(max_pad_len)
          y_padded[:len(y)] = y
          y = y_padded
        elif len(y) > max_pad_len:
          y = np.asarray(y[:max_pad_len])
        # Split audio signals into chunks
        chunks = frame(y.reshape(1, 1, -1), chunk_step, chunk_size)
        # Reshape chunks
        chunks = chunks.reshape(chunks.shape[1],chunks.shape[-1])

        # Z-normalization
        y = np.asarray(list(map(zscore, chunks)))

        # Compute mel spectrogram
        mel_spect = np.asarray(list(map(mel_spectrogram, y)))

        # Time distributed Framing
        mel_spect_ts = frame(mel_spect,hop_ts,win_ts)
        print(mel_spect_ts.shape)
        # Build X for time distributed CNN
        X = mel_spect_ts.reshape(mel_spect_ts.shape[0],
                                    mel_spect_ts.shape[1],
                                    mel_spect_ts.shape[2],
                                    mel_spect_ts.shape[3],
                                    1)
        # Predict emotion
        if predict_proba is True:
            predict = model.predict(X)
        else:
            predict = np.argmax(model.predict(X), axis=1)
            predict = [emotion1.get(emotion) for emotion in predict]



        return predict

# %%
filename='//content/test.wav'
predict=predict_emotion_from_file(model, filename, chunk_step=16000, chunk_size=49100, predict_proba=False, sample_rate=16000)
# Out:
# (1, 5, 128, 128)

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading https://files.pythonhosted.org/packages/b6/3f/cdd30cbd950efdb1fa5c766ffb2c38d1da5314292b6cd226e3871171a776/opendatasets-0.1.20-py3-none-any.whl
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.41.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2021.5.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.20

# %%
import opendatasets as od
od.download("https://www.kaggle.com/uwrfkaggler/ravdess-emotional-speech-audio")

# %%
# !rm -rf /content/ravdess-emotional-speech-audio/audio_speech_actors_01-24

# %%
sample_rate = 16000     
max_pad_len = 55000
eng_signals = []
eng_labels = []
dataset_path = '/content/ravdess-emotional-speech-audio'
actors = os.listdir(dataset_path)
for actor_file in actors:
    actor_path = os.path.join(dataset_path,actor_file)
    filenames = os.listdir(actor_path)
    for name in filenames:
        temp = int(name[6:8])
        if (temp==1) or (temp==3) or (temp==4) or (temp==5):
            if temp==1:  eng_labels.append(3)
            elif temp==3: eng_labels.append(1)
            elif temp==4: eng_labels.append(2)
            else: eng_labels.append(0)
            file_path = os.path.join(actor_path,name)
            y,sr = librosa.load(file_path, sr=sample_rate)
            y = zscore(y)
            if len(y) < max_pad_len:    
                y_padded = np.zeros(max_pad_len)
                y_padded[:len(y)] = y
                y = y_padded
            elif len(y) > max_pad_len:
                y = np.asarray(y[:max_pad_len])
            eng_signals.append(y)

eng_labels = np.array(eng_labels)
eng_signals = np.array(eng_signals)

# %%
eng_signals.shape
# Out:
# (672, 55000)

# %%
print("Data Augmentation: START")
eng_augmented_signals = list(map(noisy_signal, eng_signals))
print("Data Augmentation: END!")
# Out:
# Data Augmentation: START
# Data Augmentation: END!

# %%
# Start feature extraction
print("Feature extraction: START")

# Compute spectogram for all audio file
eng_mel_spects = np.asarray(list(map(mel_spectrogram, eng_signals)))
eng_augmented_mel_spects = [np.asarray(list(map(mel_spectrogram, eng_augmented_signals[i]))) for i in range(len(eng_augmented_signals))]

# Stop feature extraction
print("Feature extraction: END!")
# Out:
# Feature extraction: START
# Feature extraction: END!

# %%
MEL_SPECT_train, MEL_SPECT_test, AUG_MEL_SPECT_train, AUG_MEL_SPECT_test, label_train, label_test = train_test_split(eng_mel_spects, eng_augmented_mel_spects, eng_labels, test_size=0.2,random_state=42)

# Build augmented labels and train
aug_label_train = np.asarray(list(itertools.chain.from_iterable([[label] * nb_augmented for label in label_train])))
AUG_MEL_SPECT_train = np.asarray(list(itertools.chain.from_iterable(AUG_MEL_SPECT_train)))

# Concatenate original and augmented
X_train = np.concatenate((MEL_SPECT_train, AUG_MEL_SPECT_train))
y_train = np.concatenate((label_train, aug_label_train))

# Build test set
X_test = MEL_SPECT_test
y_test = label_test

# %%
X_train = frame(X_train, hop_ts, win_ts)
X_test = frame(X_test, hop_ts, win_ts)

# %%
lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(np.ravel(y_train)))
y_test = np_utils.to_categorical(lb.transform(np.ravel(y_test)))
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , X_train.shape[2], X_train.shape[3], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] , X_test.shape[2], X_test.shape[3], 1)

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
Y_pred=model.predict(X_test)
Y_pred=np.argmax(Y_pred,axis=1)
y_true=np.argmax(y_test,axis=1)
cm = confusion_matrix(y_true,Y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                colorbar=True,
                                show_absolute=True,
                                show_normed=True,
                                )
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.61        49
#            1       0.30      0.10      0.15        29
#            2       0.38      0.39      0.39        38
#            3       0.19      0.26      0.22        19
#
#     accuracy                           0.41       135
#    macro avg       0.36      0.36      0.34       135
# weighted avg       0.40      0.41      0.39       135
